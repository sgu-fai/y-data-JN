# %% [markdown]
# # Assignment: Unsupervised Machine Learning \ Clustering

# %% [markdown]
# In this assignment you will continue the experience you've done with clustering - this time, via hierarchical clustering and DBSCAN.

# %% [markdown]
# ## Part 1: Hierarchical Clustering
# (Practice material by Etam Benger)
#
# In this part we are going to experiment with Hierarchical Clustering, a very powerfull clustering technique that can easily be interperted and explained via the dendrgoram.
#
# The analyses are made on real datasets under the circumstances of real life challenges in unsupervised machine learning.

# %% [markdown]
# ### Different ways to calculate the distance between clusters can yield strikingly different results

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.cluster import OPTICS
from sklearn.cluster import KMeans
from scipy.spatial.distance import squareform
from scipy.cluster import hierarchy
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
# Labels
l = ['A', 'B', 'C', 'D', 'E', 'F']

# Distance matrix
# (Note that it must be symmetrical and its diagonal is always 0)
d = np.array([[0, 1, 3, 3, 3, 4],
              [1, 0, 4, 2, 3, 2],
              [3, 4, 0, 3, 2, 5],
              [3, 2, 3, 0, 2, 4],
              [3, 3, 2, 2, 0, 5],
              [4, 2, 5, 4, 5, 0]])

# %%
# The hierarchy.linkage function uses a condensed distance matrix,
# which is a flattened vector of the upper right triangle of the matrix:
# (Caution! If you use the distance matrix as is, you will get erroneous
# results -- in that case the algorithm will assume that each row is a
# vector that represents the respective point, and will calculate the
# euclidean distance between those vectors, which is absolute nonsense.)
squareform(d)
# Out:
# array([1, 3, 3, 3, 4, 4, 2, 3, 2, 3, 2, 5, 2, 4, 5])

# %%
# Please read the documentation here:
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.linkage.html
#
# As you'll see below, the different methods of linkage may produce very different structures
# and, consequently, very different clusters. Try to understand why (look at the distance matrix
# and follow the formulas in the documentation).
# Sometimes the characteristics of the problem suggest what method is more natural to use than
# the others. This is especially true with respect to the complete (= farthest point) and single
# (= nearest point) methods. Other times the 'correct' method to use is not obvious at all, and
# it requires inspecting the results and the data thoroughly. The average method usually works
# well, however.

methods = ['single', 'complete', 'average', 'ward']  # There are other methods as well, see documentation

plt.figure(figsize=(10, 5))

for i, method in enumerate(methods):
    plt.subplot(2, 2, i+1)
    plt.title(method)
    
    ############# This is the relevant part: #############
    #                                                    #
    lnk = hierarchy.linkage(squareform(d), method)
    hierarchy.dendrogram(lnk, labels=l, color_threshold=0)
    #                                                    #
    ######################################################
    
    plt.ylim(0, 5.5)
    plt.grid(axis='y')

plt.tight_layout()

# %% [markdown]
# ### Altering the order in which clusters are joined can also yield strikingly different results

# %%
# Labels
l = ['A', 'B', 'C', 'D', 'E']

# Distance matrices
epsilon = 10**-16
a, b = 1 + epsilon, 1 - epsilon

d1 = np.array([[0, 1, a, 5, 5],
               [1, 0, 3, 5, 5],
               [a, 3, 0, 3, b],
               [5, 5, 3, 0, 1],
               [5, 5, b, 1, 0]])

d2 = np.array([[0, 1, b, 5, 5],
               [1, 0, 3, 5, 5],
               [b, 3, 0, 3, a],
               [5, 5, 3, 0, 1],
               [5, 5, a, 1, 0]])

# %%
# The Frobenius distance between the matrices is negligible
np.sqrt(np.sum((d1-d2)**2))
# Out:
# 2.220446049250313e-16

# %%
# But the resulting clusters are very different!

plt.figure(figsize=(10, 3))

for i, d in enumerate([d1, d2]):
    plt.subplot(1, 2, i+1)
    plt.title('d%s' % (i+1,))

    lnk = hierarchy.linkage(squareform(d), 'complete') # You can experiment with the different methods ('single', 'complete', 'average', 'ward')
    hierarchy.dendrogram(lnk, labels=l, color_threshold=0)

    plt.ylim(0, 6)
    plt.grid(axis='y')

plt.tight_layout()

# %% [markdown]
# ## Challenge 1.1
# Data preparation and preprocessing can help in reducing such "hypersensitivity". One of the techniques is to clean the distance matrix from noise before the actual clustering. This can be done by... clustering. Your mission, should you choose to accept it, is to:
# 1. Apply the K-Means algorithm to clean the distance matrix, assuming the correct number of clusters is 4. (Clustering can be made on each matrix independently, although in some cases it's wiser to do a cross-matrix clustering).
# 2. Create new cleaned versions of the distance matrices (d1_clean and d2_clean)
# 3. Repeat the above process

# %%
print("I don't understand result of line 1 & 4")
print("%20.19f"%(d1[0,2]))
print("%18.16f"%(d1[2,4]))
print("%18.16f"%(epsilon))
print("%18.16f"%(a))
print("%18.16f"%(b))
# Out:
# I don't understand result of line 1 & 4
# 1.0000000000000000000
# 0.9999999999999999
# 0.0000000000000001
# 1.0000000000000000
# 0.9999999999999999

# %%
km = KMeans(4)
vec_shape = d2.shape
km.fit(d2.reshape(-1, 1))
# d1bis = km.cluster_centers_.flatten()[km.predict(d1.reshape(-1, 1))].reshape(vec_shape)
# d2bis = km.cluster_centers_.flatten()[km.predict(d2.reshape(-1, 1))].reshape(vec_shape)

d1bis = squareform(km.cluster_centers_.flatten()[km.predict(squareform(d1).reshape(-1, 1))])
d2bis = squareform(km.cluster_centers_.flatten()[km.predict(squareform(d2).reshape(-1, 1))])

for i, d in enumerate([d1bis, d2bis]):
    plt.subplot(1, 2, i+1)
    plt.title('d%s' % (i+1,))

    lnk = hierarchy.linkage(squareform(d), 'complete') # You can experiment with the different methods ('single', 'complete', 'average', 'ward')
    hierarchy.dendrogram(lnk, labels=l, color_threshold=0)

    plt.ylim(0, 6)
    plt.grid(axis='y')

plt.tight_layout()

# %% [markdown]
# ### Analyzing voting data
#
# We can also use hierarchical clustering to analyzie election voting data, as we will see in the following exercise

# %%
df = pd.read_csv('Elections.csv')

# Show first 10 rows
df[:10]
# Out:
#    TownNumber       TownName  Potential  TotalVotes  PercentVote  Qualified  \
# 0        5000  תל אביב - יפו     383990      226390        58.96     224000
# 1        3000        ירושלים     353784      217905        61.59     215743
# 2        4000           חיפה     235198      136506        58.04     134710
# 3        8300    ראשון לציון     182953      117147        64.03     115839
# 4        7900      פתח תקווה     155678      100123        64.31      98905
# 5          70          אשדוד     156977       96363        61.39      94776
# 6        6600          חולון     149023       88202        59.19      86962
# 7        7400          נתניה     150183       82783        55.12      81367
# 8        9000        באר שבע     148214       79215        53.45      77853
# 9        8600         רמת גן     119271       75684        63.46      74932
#
#    Disqualified  Avoda  Or  BaitYehudi  ...  Brit  Gever  Zomet  Zabar  Daam  \
# 0          2390  34095  77        3417  ...    36     41     42    273   198
# 1          2162  12355  38        8944  ...    26     19     23    147    64
# 2          1796  17279  43        3431  ...    13     29     67    218    89
# 3          1308  12647  25        2451  ...    22     22     24    238    63
# 4          1218   8661  20        6043  ...    19     16     21     90    45
# 5          1587   4176  23        1399  ...    14     31     26    139    93
# 6          1240   9439  22        1409  ...    21     24     20    129    55
# 7          1416   5928  33        3462  ...    22     35     43    113    68
# 8          1362   5577  19        1608  ...    17     29     16    109    69
# 9           752  11023  32        2185  ...    11     22     21     95    27
#
#    AleYarok  Koah.2  Lidar  Yarok   Shas
# 0      1003      50     41   1081  14412
# 1       434      26     39    445  32624
# 2       485      41     37    467   4117
# 3       454      30     30    580   6784
# 4       330      41     32    341   8061
# 5       294      27    103    212  14065
# 6       326      25     24    344   9250
# 7       285      23     45    302   8837
# 8       227      27     41    189   8491
# 9       293      18     17    452   3709
#
# [10 rows x 41 columns]

# %%
n=100
for i, row in df[:n].iterrows():
    print("i:{}. row:{}".format(i, row))
# Out:
# i:0. row:TownNumber                5000
# TownName         תל אביב - יפו
# Potential               383990
# TotalVotes              226390
# PercentVote              58.96
# Qualified               224000
# Disqualified              2390
# Avoda                    34095
# Or                          77
# BaitYehudi                3417
# YahadutHatora             2245
# Balad                      673
# MeimadYarukim             3052
# Hadash                    5203
# Gimlaim                   1817
# EfraimSne                  457
# IhudLeumi                 2751
# Israelim                    57
# Lev                         52
# NizolimAndAle              159
# Kadima                   75785
# IsraelBeytenu            13644
# Likud                    43318
# Merez                    17207
# Nudelman                    53
# RuahHadasha                 42
# Lazuz                       36
# LojmeiHevra                 34
# Raam                      2451
# Koah                       198
# Koah.1                       0
# Brit                        36
# Gever                       41
# Zomet                       42
# Zabar                      273
# Daam                       198
# AleYarok                  1003
# Koah.2                      50
# Lidar                       41
# Yarok                     1081
# Shas                     14412
# Name: 0, dtype: object
# i:1. row:TownNumber          3000
# TownName         ירושלים
# Potential         353784
# TotalVotes        217905
# PercentVote        61.59
# Qualified         215743
# Disqualified        2162
# Avoda              12355
# Or                    38
# BaitYehudi          8944
# YahadutHatora      40928
# Balad                530
# MeimadYarukim       4519
# Hadash              1470
# Gimlaim              942
# EfraimSne            227
# IhudLeumi          14260
# Israelim              41
# Lev                   24
# NizolimAndAle         83
# Kadima             24803
# IsraelBeytenu      13694
# Likud              51018
# Merez               7181
# Nudelman              75
# RuahHadasha          101
# Lazuz                 15
# LojmeiHevra           16
# Raam                 546
# Koah                  86
# Koah.1                 0
# Brit                  26
# Gever                 19
# Zomet                 23
# Zabar                147
# Daam                  64
# AleYarok             434
# Koah.2                26
# Lidar                 39
# Yarok                445
# Shas               32624
# Name: 1, dtype: object
# i:2. row:TownNumber         4000
# TownName           חיפה
# Potential        235198
# TotalVotes       136506
# PercentVote       58.04
# Qualified        134710
# Disqualified       1796
# Avoda             17279
# Or                   43
# BaitYehudi         3431
# YahadutHatora      3060
# Balad              2771
# MeimadYarukim      1049
# Hadash             5533
# Gimlaim            1522
# EfraimSne           320
# IhudLeumi          2165
# Israelim             29
# Lev                  20
# NizolimAndAle        96
# Kadima            38196
# IsraelBeytenu     21948
# Likud             26693
# Merez              4140
# Nudelman            243
# RuahHadasha          31
# Lazuz                18
# LojmeiHevra          32
# Raam                434
# Koah                 94
# Koah.1                0
# Brit                 13
# Gever                29
# Zomet                67
# Zabar               218
# Daam                 89
# AleYarok            485
# Koah.2               41
# Lidar                37
# Yarok               467
# Shas               4117
# Name: 2, dtype: object
# i:3. row:TownNumber              8300
# TownName         ראשון לציון
# Potential             182953
# TotalVotes            117147
# PercentVote            64.03
# Qualified             115839
# Disqualified            1308
# Avoda                  12647
# Or                        25
# BaitYehudi              2451
# YahadutHatora            636
# Balad                     27
# MeimadYarukim            495
# Hadash                   138
# Gimlaim                  738
# EfraimSne                264
# IhudLeumi               1649
# Israelim                  23
# Lev                       26
# NizolimAndAle             72
# Kadima                 37663
# IsraelBeytenu          16779
# Likud                  31524
# Merez                   1957
# Nudelman                 159
# RuahHadasha               13
# Lazuz                     18
# LojmeiHevra               22
# Raam                      18
# Koah                     248
# Koah.1                     0
# Brit                      22
# Gever                     22
# Zomet                     24
# Zabar                    238
# Daam                      63
# AleYarok                 454
# Koah.2                    30
# Lidar                     30
# Yarok                    580
# Shas                    6784
# Name: 3, dtype: object
# i:4. row:TownNumber            7900
# TownName         פתח תקווה
# Potential           155678
# TotalVotes          100123
# PercentVote          64.31
# Qualified            98905
# Disqualified          1218
# Avoda                 8661
# Or                      20
# BaitYehudi            6043
# YahadutHatora         3398
# Balad                   24
# MeimadYarukim          412
# Hadash                 105
# Gimlaim                748
# EfraimSne              240
# IhudLeumi             4114
# Israelim                12
# Lev                     25
# NizolimAndAle           64
# Kadima               23405
# IsraelBeytenu        14836
# Likud                25884
# Merez                 1539
# Nudelman               141
# RuahHadasha             19
# Lazuz                   15
# LojmeiHevra             22
# Raam                    21
# Koah                   161
# Koah.1                   0
# Brit                    19
# Gever                   16
# Zomet                   21
# Zabar                   90
# Daam                    45
# AleYarok               330
# Koah.2                  41
# Lidar                   32
# Yarok                  341
# Shas                  8061
# Name: 4, dtype: object
# i:5. row:TownNumber           70
# TownName          אשדוד
# Potential        156977
# TotalVotes        96363
# PercentVote       61.39
# Qualified         94776
# Disqualified       1587
# Avoda              4176
# Or                   23
# BaitYehudi         1399
# YahadutHatora      8101
# Balad                43
# MeimadYarukim       179
# Hadash               46
# Gimlaim             436
# EfraimSne           109
# IhudLeumi          1359
# Israelim             17
# Lev                  29
# NizolimAndAle        46
# Kadima            14896
# IsraelBeytenu     24693
# Likud             23191
# Merez               738
# Nudelman            129
# RuahHadasha          16
# Lazuz                26
# LojmeiHevra          24
# Raam                 37
# Koah                 59
# Koah.1                0
# Brit                 14
# Gever                31
# Zomet                26
# Zabar               139
# Daam                 93
# AleYarok            294
# Koah.2               27
# Lidar               103
# Yarok               212
# Shas              14065
# Name: 5, dtype: object
# i:6. row:TownNumber         6600
# TownName          חולון
# Potential        149023
# TotalVotes        88202
# PercentVote       59.19
# Qualified         86962
# Disqualified       1240
# Avoda              9439
# Or                   22
# BaitYehudi         1409
# YahadutHatora       450
# Balad                18
# MeimadYarukim       321
# Hadash              137
# Gimlaim             760
# EfraimSne           227
# IhudLeumi          1100
# Israelim              4
# Lev                  27
# NizolimAndAle        65
# Kadima            26004
# IsraelBeytenu     10815
# Likud             24253
# Merez              1498
# Nudelman             40
# RuahHadasha           7
# Lazuz                11
# LojmeiHevra          15
# Raam                 23
# Koah                 99
# Koah.1                0
# Brit                 21
# Gever                24
# Zomet                20
# Zabar               129
# Daam                 55
# AleYarok            326
# Koah.2               25
# Lidar                24
# Yarok               344
# Shas               9250
# Name: 6, dtype: object
# i:7. row:TownNumber         7400
# TownName          נתניה
# Potential        150183
# TotalVotes        82783
# PercentVote       55.12
# Qualified         81367
# Disqualified       1416
# Avoda              5928
# Or                   33
# BaitYehudi         3462
# YahadutHatora      1849
# Balad                33
# MeimadYarukim       279
# Hadash               66
# Gimlaim             510
# EfraimSne           181
# IhudLeumi          2654
# Israelim             22
# Lev                  23
# NizolimAndAle        53
# Kadima            18579
# IsraelBeytenu     13299
# Likud             23129
# Merez               993
# Nudelman            280
# RuahHadasha          20
# Lazuz                10
# LojmeiHevra           9
# Raam                 28
# Koah                154
# Koah.1                0
# Brit                 22
# Gever                35
# Zomet                43
# Zabar               113
# Daam                 68
# AleYarok            285
# Koah.2               23
# Lidar                45
# Yarok               302
# Shas               8837
# Name: 7, dtype: object
# i:8. row:TownNumber          9000
# TownName         באר שבע
# Potential         148214
# TotalVotes         79215
# PercentVote        53.45
# Qualified          77853
# Disqualified        1362
# Avoda               5577
# Or                    19
# BaitYehudi          1608
# YahadutHatora        533
# Balad                 88
# MeimadYarukim        274
# Hadash               200
# Gimlaim              476
# EfraimSne            168
# IhudLeumi           1970
# Israelim              15
# Lev                   35
# NizolimAndAle         59
# Kadima             15257
# IsraelBeytenu      19447
# Likud              21657
# Merez                880
# Nudelman             150
# RuahHadasha           22
# Lazuz                 23
# LojmeiHevra           33
# Raam                  94
# Koah                  53
# Koah.1                 0
# Brit                  17
# Gever                 29
# Zomet                 16
# Zabar                109
# Daam                  69
# AleYarok             227
# Koah.2                27
# Lidar                 41
# Yarok                189
# Shas                8491
# Name: 8, dtype: object
# i:9. row:TownNumber         8600
# TownName         רמת גן
# Potential        119271
# TotalVotes        75684
# PercentVote       63.46
# Qualified         74932
# Disqualified        752
# Avoda             11023
# Or                   32
# BaitYehudi         2185
# YahadutHatora       531
# Balad                12
# MeimadYarukim       648
# Hadash              304
# Gimlaim            1011
# EfraimSne           314
# IhudLeumi          1776
# Israelim             20
# Lev                  11
# NizolimAndAle        49
# Kadima            25590
# IsraelBeytenu      5270
# Likud             18441
# Merez              2881
# Nudelman             25
# RuahHadasha          12
# Lazuz                12
# LojmeiHevra          15
# Raam                 12
# Koah                 93
# Koah.1                0
# Brit                 11
# Gever                22
# Zomet                21
# Zabar                95
# Daam                 27
# AleYarok            293
# Koah.2               18
# Lidar                17
# Yarok               452
# Shas               3709
# Name: 9, dtype: object
# i:10. row:TownNumber          6100
# TownName         בני ברק
# Potential          88252
# TotalVotes         63936
# PercentVote        72.45
# Qualified          63433
# Disqualified         503
# Avoda                654
# Or                    14
# BaitYehudi          1530
# YahadutHatora      34802
# Balad                  6
# MeimadYarukim         61
# Hadash                25
# Gimlaim              113
# EfraimSne             19
# IhudLeumi           1994
# Israelim               4
# Lev                    3
# NizolimAndAle         15
# Kadima              1598
# IsraelBeytenu       1362
# Likud               3506
# Merez                138
# Nudelman              18
# RuahHadasha            4
# Lazuz                  3
# LojmeiHevra            3
# Raam                  17
# Koah                  21
# Koah.1                 0
# Brit                   2
# Gever                  4
# Zomet                  2
# Zabar                 16
# Daam                   6
# AleYarok              37
# Koah.2                 3
# Lidar                  6
# Yarok                 34
# Shas               17413
# Name: 10, dtype: object
# i:11. row:TownNumber         6200
# TownName          בת ים
# Potential        124257
# TotalVotes        62926
# PercentVote       50.64
# Qualified         61855
# Disqualified       1071
# Avoda              4552
# Or                   19
# BaitYehudi         1067
# YahadutHatora       442
# Balad                28
# MeimadYarukim       133
# Hadash              115
# Gimlaim             626
# EfraimSne           126
# IhudLeumi          1639
# Israelim             16
# Lev                  28
# NizolimAndAle        51
# Kadima            15151
# IsraelBeytenu     13653
# Likud             16023
# Merez               646
# Nudelman             88
# RuahHadasha          14
# Lazuz                13
# LojmeiHevra           9
# Raam                 23
# Koah                 60
# Koah.1                0
# Brit                 18
# Gever                17
# Zomet                15
# Zabar               103
# Daam                 65
# AleYarok            256
# Koah.2               26
# Lidar                42
# Yarok               221
# Shas               6570
# Name: 11, dtype: object
# i:12. row:TownNumber         8400
# TownName         רחובות
# Potential         88121
# TotalVotes        56337
# PercentVote       63.93
# Qualified         55671
# Disqualified        666
# Avoda              5897
# Or                   21
# BaitYehudi         2204
# YahadutHatora      1685
# Balad                12
# MeimadYarukim       584
# Hadash              125
# Gimlaim             395
# EfraimSne           123
# IhudLeumi          2681
# Israelim              9
# Lev                  15
# NizolimAndAle        23
# Kadima            13756
# IsraelBeytenu      6981
# Likud             14469
# Merez              1589
# Nudelman             34
# RuahHadasha          20
# Lazuz                 7
# LojmeiHevra          11
# Raam                 20
# Koah                 41
# Koah.1                0
# Brit                  5
# Gever                26
# Zomet                11
# Zabar                65
# Daam                 27
# AleYarok            187
# Koah.2               18
# Lidar                59
# Yarok               221
# Shas               4350
# Name: 12, dtype: object
# i:13. row:TownNumber         7100
# TownName         אשקלון
# Potential         89652
# TotalVotes        50644
# PercentVote       56.49
# Qualified         49795
# Disqualified        849
# Avoda              2812
# Or                   11
# BaitYehudi         1027
# YahadutHatora       488
# Balad                34
# MeimadYarukim       132
# Hadash               32
# Gimlaim             297
# EfraimSne            86
# IhudLeumi          1424
# Israelim             13
# Lev                  26
# NizolimAndAle        27
# Kadima             7978
# IsraelBeytenu     13631
# Likud             15358
# Merez               351
# Nudelman            140
# RuahHadasha           8
# Lazuz                 9
# LojmeiHevra          17
# Raam                 17
# Koah                 37
# Koah.1                0
# Brit                 19
# Gever                18
# Zomet                15
# Zabar                78
# Daam                 45
# AleYarok            169
# Koah.2               23
# Lidar                16
# Yarok               101
# Shas               5356
# Name: 13, dtype: object
# i:14. row:TownNumber         6400
# TownName         הרצליה
# Potential         74585
# TotalVotes        48046
# PercentVote       64.42
# Qualified         47558
# Disqualified        488
# Avoda              7341
# Or                   18
# BaitYehudi          903
# YahadutHatora       314
# Balad                 8
# MeimadYarukim       388
# Hadash              165
# Gimlaim             339
# EfraimSne           227
# IhudLeumi           795
# Israelim             16
# Lev                   5
# NizolimAndAle        28
# Kadima            17589
# IsraelBeytenu      3536
# Likud             10786
# Merez              2224
# Nudelman             15
# RuahHadasha           1
# Lazuz                 7
# LojmeiHevra           9
# Raam                  7
# Koah                 64
# Koah.1                0
# Brit                  8
# Gever                10
# Zomet                10
# Zabar                51
# Daam                 30
# AleYarok            219
# Koah.2               10
# Lidar                10
# Yarok               255
# Shas               2170
# Name: 14, dtype: object
# i:15. row:TownNumber          6900
# TownName         כפר סבא
# Potential          68488
# TotalVotes         46490
# PercentVote        67.88
# Qualified          46066
# Disqualified         424
# Avoda               6879
# Or                    17
# BaitYehudi          1128
# YahadutHatora        207
# Balad                  7
# MeimadYarukim        431
# Hadash               126
# Gimlaim              252
# EfraimSne            144
# IhudLeumi            973
# Israelim               9
# Lev                    3
# NizolimAndAle         41
# Kadima             16491
# IsraelBeytenu       4105
# Likud              10448
# Merez               2023
# Nudelman              11
# RuahHadasha            9
# Lazuz                  4
# LojmeiHevra            9
# Raam                   8
# Koah                  55
# Koah.1                 0
# Brit                   9
# Gever                  9
# Zomet                 12
# Zabar                 62
# Daam                  18
# AleYarok             192
# Koah.2                12
# Lidar                 10
# Yarok                253
# Shas                2109
# Name: 15, dtype: object
# i:16. row:TownNumber        8700
# TownName         רעננה
# Potential        58594
# TotalVotes       39669
# PercentVote       67.7
# Qualified        39385
# Disqualified       284
# Avoda             5540
# Or                  10
# BaitYehudi        1873
# YahadutHatora      319
# Balad                1
# MeimadYarukim      491
# Hadash              87
# Gimlaim            184
# EfraimSne           90
# IhudLeumi         1463
# Israelim             8
# Lev                  5
# NizolimAndAle       17
# Kadima           14724
# IsraelBeytenu     2021
# Likud             9150
# Merez             1565
# Nudelman             7
# RuahHadasha         12
# Lazuz                4
# LojmeiHevra          4
# Raam                 1
# Koah                33
# Koah.1               0
# Brit                 1
# Gever                5
# Zomet                1
# Zabar               36
# Daam                10
# AleYarok           136
# Koah.2               5
# Lidar                8
# Yarok              199
# Shas              1375
# Name: 16, dtype: object
# i:17. row:TownNumber        6500
# TownName          חדרה
# Potential        64242
# TotalVotes       36089
# PercentVote      56.18
# Qualified        35440
# Disqualified       649
# Avoda             2784
# Or                  14
# BaitYehudi         803
# YahadutHatora      768
# Balad               24
# MeimadYarukim      135
# Hadash              63
# Gimlaim            264
# EfraimSne           66
# IhudLeumi          615
# Israelim             6
# Lev                 11
# NizolimAndAle       25
# Kadima            9110
# IsraelBeytenu     6904
# Likud             9839
# Merez              481
# Nudelman            68
# RuahHadasha         13
# Lazuz                7
# LojmeiHevra         17
# Raam                44
# Koah                36
# Koah.1               0
# Brit                 8
# Gever               16
# Zomet               11
# Zabar               63
# Daam                37
# AleYarok           139
# Koah.2              21
# Lidar               22
# Yarok              107
# Shas              2919
# Name: 17, dtype: object
# i:18. row:TownNumber                    1200
# TownName         מודיעין-מכבים-רעו
# Potential                    42244
# TotalVotes                   31971
# PercentVote                  75.68
# Qualified                    31781
# Disqualified                   190
# Avoda                         4487
# Or                               4
# BaitYehudi                    1559
# YahadutHatora                  118
# Balad                            5
# MeimadYarukim                  632
# Hadash                          55
# Gimlaim                        103
# EfraimSne                       64
# IhudLeumi                      897
# Israelim                         3
# Lev                              0
# NizolimAndAle                   19
# Kadima                       10958
# IsraelBeytenu                 2208
# Likud                         8348
# Merez                         1234
# Nudelman                        13
# RuahHadasha                      5
# Lazuz                           10
# LojmeiHevra                      1
# Raam                             1
# Koah                            22
# Koah.1                           0
# Brit                             4
# Gever                            2
# Zomet                            1
# Zabar                           31
# Daam                             3
# AleYarok                        79
# Koah.2                           6
# Lidar                            0
# Yarok                          165
# Shas                           744
# Name: 18, dtype: object
# i:19. row:TownNumber          6300
# TownName         גבעתיים
# Potential          43584
# TotalVotes         29566
# PercentVote        67.84
# Qualified          29284
# Disqualified         282
# Avoda               5777
# Or                     9
# BaitYehudi           718
# YahadutHatora        131
# Balad                  2
# MeimadYarukim        305
# Hadash               173
# Gimlaim              370
# EfraimSne            119
# IhudLeumi            431
# Israelim               8
# Lev                    2
# NizolimAndAle         23
# Kadima             11105
# IsraelBeytenu       1406
# Likud               5863
# Merez               1802
# Nudelman               1
# RuahHadasha            5
# Lazuz                  3
# LojmeiHevra            1
# Raam                   5
# Koah                  27
# Koah.1                 0
# Brit                   3
# Gever                  5
# Zomet                  2
# Zabar                 36
# Daam                  21
# AleYarok             119
# Koah.2                 6
# Lidar                  7
# Yarok                165
# Shas                 634
# Name: 19, dtype: object
# i:20. row:TownNumber        7000
# TownName           לוד
# Potential        50723
# TotalVotes       28094
# PercentVote      55.39
# Qualified        27475
# Disqualified       619
# Avoda             1223
# Or                   9
# BaitYehudi         625
# YahadutHatora      137
# Balad             1012
# MeimadYarukim       46
# Hadash             667
# Gimlaim            133
# EfraimSne           30
# IhudLeumi         1070
# Israelim            16
# Lev                  6
# NizolimAndAle       10
# Kadima            3789
# IsraelBeytenu     6031
# Likud             6543
# Merez              192
# Nudelman            39
# RuahHadasha         10
# Lazuz               20
# LojmeiHevra          6
# Raam              1860
# Koah                29
# Koah.1               0
# Brit                 8
# Gever               15
# Zomet               24
# Zabar               37
# Daam                27
# AleYarok            85
# Koah.2              11
# Lidar               13
# Yarok               53
# Shas              3699
# Name: 20, dtype: object
# i:21. row:TownNumber        9100
# TownName         נהריה
# Potential        43940
# TotalVotes       26138
# PercentVote      59.49
# Qualified        25793
# Disqualified       345
# Avoda             2357
# Or                  10
# BaitYehudi         474
# YahadutHatora      198
# Balad               20
# MeimadYarukim       74
# Hadash              59
# Gimlaim            180
# EfraimSne          106
# IhudLeumi          491
# Israelim            10
# Lev                  8
# NizolimAndAle       24
# Kadima            6651
# IsraelBeytenu     5706
# Likud             6891
# Merez              348
# Nudelman            14
# RuahHadasha         10
# Lazuz                5
# LojmeiHevra         10
# Raam                 9
# Koah                18
# Koah.1               0
# Brit                12
# Gever               15
# Zomet               24
# Zabar               39
# Daam                10
# AleYarok           112
# Koah.2              11
# Lidar               10
# Yarok              118
# Shas              1769
# Name: 21, dtype: object
# i:22. row:TownNumber        8500
# TownName          רמלה
# Potential        48009
# TotalVotes       25949
# PercentVote      54.05
# Qualified        25240
# Disqualified       709
# Avoda             1287
# Or                   2
# BaitYehudi         304
# YahadutHatora       89
# Balad              630
# MeimadYarukim      169
# Hadash             914
# Gimlaim             92
# EfraimSne           44
# IhudLeumi          495
# Israelim            16
# Lev                 18
# NizolimAndAle       16
# Kadima            3611
# IsraelBeytenu     3850
# Likud             7470
# Merez              207
# Nudelman            14
# RuahHadasha          9
# Lazuz               13
# LojmeiHevra         17
# Raam              1720
# Koah                17
# Koah.1               0
# Brit                10
# Gever               20
# Zomet               10
# Zabar               44
# Daam                37
# AleYarok            67
# Koah.2              14
# Lidar               14
# Yarok               47
# Shas              3973
# Name: 22, dtype: object
# i:23. row:TownNumber           6800
# TownName         קרית אתא
# Potential           41963
# TotalVotes          25339
# PercentVote         60.38
# Qualified           24906
# Disqualified          433
# Avoda                1745
# Or                      7
# BaitYehudi            913
# YahadutHatora         411
# Balad                   9
# MeimadYarukim          60
# Hadash                 29
# Gimlaim               145
# EfraimSne              43
# IhudLeumi             737
# Israelim                3
# Lev                     3
# NizolimAndAle          13
# Kadima               5950
# IsraelBeytenu        4988
# Likud                7090
# Merez                 176
# Nudelman               37
# RuahHadasha             2
# Lazuz                   4
# LojmeiHevra             6
# Raam                    4
# Koah                   25
# Koah.1                  0
# Brit                    4
# Gever                   8
# Zomet                   9
# Zabar                  55
# Daam                   23
# AleYarok               85
# Koah.2                 12
# Lidar                  11
# Yarok                  89
# Shas                 2210
# Name: 23, dtype: object
# i:24. row:TownNumber            9700
# TownName         הוד השרון
# Potential            34051
# TotalVotes           24495
# PercentVote          71.94
# Qualified            24306
# Disqualified           189
# Avoda                 4075
# Or                       5
# BaitYehudi             279
# YahadutHatora           71
# Balad                    5
# MeimadYarukim          231
# Hadash                  76
# Gimlaim                105
# EfraimSne               98
# IhudLeumi              220
# Israelim                 1
# Lev                      1
# NizolimAndAle           17
# Kadima                9868
# IsraelBeytenu         1462
# Likud                 5445
# Merez                 1063
# Nudelman                 9
# RuahHadasha              2
# Lazuz                    1
# LojmeiHevra              1
# Raam                     5
# Koah                    32
# Koah.1                   0
# Brit                     1
# Gever                    8
# Zomet                    4
# Zabar                   22
# Daam                     8
# AleYarok               101
# Koah.2                   2
# Lidar                    2
# Yarok                  137
# Shas                   949
# Name: 24, dtype: object
# i:25. row:TownNumber          2610
# TownName         בית שמש
# Potential          38591
# TotalVotes         23790
# PercentVote        61.65
# Qualified          23471
# Disqualified         319
# Avoda                625
# Or                     2
# BaitYehudi          1442
# YahadutHatora       4829
# Balad                 10
# MeimadYarukim         89
# Hadash                19
# Gimlaim               24
# EfraimSne             10
# IhudLeumi           1784
# Israelim               8
# Lev                    4
# NizolimAndAle          7
# Kadima              1449
# IsraelBeytenu       2800
# Likud               5204
# Merez                 95
# Nudelman              16
# RuahHadasha            3
# Lazuz                  4
# LojmeiHevra            6
# Raam                   7
# Koah                  12
# Koah.1                 0
# Brit                   4
# Gever                  3
# Zomet                  1
# Zabar                 16
# Daam                  10
# AleYarok              34
# Koah.2                 6
# Lidar                  5
# Yarok                 34
# Shas                4909
# Name: 25, dtype: object
# i:26. row:TownNumber         1139
# TownName         כרמיאל
# Potential         38864
# TotalVotes        23494
# PercentVote       60.45
# Qualified         23041
# Disqualified        453
# Avoda              1805
# Or                    5
# BaitYehudi          301
# YahadutHatora       393
# Balad                47
# MeimadYarukim        98
# Hadash              116
# Gimlaim              65
# EfraimSne            38
# IhudLeumi           310
# Israelim              3
# Lev                   3
# NizolimAndAle        10
# Kadima             5837
# IsraelBeytenu      7413
# Likud              5087
# Merez               360
# Nudelman             20
# RuahHadasha           5
# Lazuz                 6
# LojmeiHevra           6
# Raam                 29
# Koah                 20
# Koah.1                0
# Brit                  4
# Gever                 4
# Zomet                19
# Zabar                35
# Daam                 23
# AleYarok            110
# Koah.2                8
# Lidar                11
# Yarok                74
# Shas                776
# Name: 26, dtype: object
# i:27. row:TownNumber            2650
# TownName         רמת השרון
# Potential            32738
# TotalVotes           23007
# PercentVote          70.28
# Qualified            22851
# Disqualified           156
# Avoda                 4494
# Or                       4
# BaitYehudi             187
# YahadutHatora          399
# Balad                    6
# MeimadYarukim          176
# Hadash                 123
# Gimlaim                125
# EfraimSne               53
# IhudLeumi              230
# Israelim                 3
# Lev                      0
# NizolimAndAle           14
# Kadima                9344
# IsraelBeytenu          839
# Likud                 4321
# Merez                 1483
# Nudelman                 0
# RuahHadasha              9
# Lazuz                    0
# LojmeiHevra              0
# Raam                     2
# Koah                    14
# Koah.1                   0
# Brit                     1
# Gever                    4
# Zomet                    6
# Zabar                   17
# Daam                     7
# AleYarok                92
# Koah.2                   2
# Lidar                    2
# Yarok                  114
# Shas                   780
# Name: 27, dtype: object
# i:28. row:TownNumber        7600
# TownName           עכו
# Potential        38794
# TotalVotes       22718
# PercentVote      58.56
# Qualified        22244
# Disqualified       474
# Avoda              849
# Or                   3
# BaitYehudi         283
# YahadutHatora      103
# Balad             3125
# MeimadYarukim       25
# Hadash            1668
# Gimlaim             61
# EfraimSne           16
# IhudLeumi          464
# Israelim             3
# Lev                  7
# NizolimAndAle        8
# Kadima            2701
# IsraelBeytenu     4910
# Likud             4971
# Merez               99
# Nudelman             7
# RuahHadasha          1
# Lazuz                6
# LojmeiHevra          4
# Raam               495
# Koah                10
# Koah.1               0
# Brit                 4
# Gever                9
# Zomet               24
# Zabar               23
# Daam                42
# AleYarok            48
# Koah.2               5
# Lidar                9
# Yarok               35
# Shas              2226
# Name: 28, dtype: object
# i:29. row:TownNumber          2630
# TownName         קרית גת
# Potential          37341
# TotalVotes         22667
# PercentVote         60.7
# Qualified          22236
# Disqualified         431
# Avoda               1035
# Or                     2
# BaitYehudi           525
# YahadutHatora        824
# Balad                 12
# MeimadYarukim         43
# Hadash                13
# Gimlaim              103
# EfraimSne             25
# IhudLeumi            754
# Israelim               4
# Lev                    7
# NizolimAndAle          9
# Kadima              3333
# IsraelBeytenu       5667
# Likud               5864
# Merez                131
# Nudelman              34
# RuahHadasha            7
# Lazuz                  0
# LojmeiHevra            6
# Raam                  16
# Koah                  22
# Koah.1                 0
# Brit                   6
# Gever                 12
# Zomet                  4
# Zabar                 40
# Daam                  33
# AleYarok              88
# Koah.2                14
# Lidar                 11
# Yarok                 41
# Shas                3551
# Name: 29, dtype: object
# i:30. row:TownNumber        7300
# TownName          נצרת
# Potential        47041
# TotalVotes       22506
# PercentVote      47.84
# Qualified        22137
# Disqualified       369
# Avoda              279
# Or                   2
# BaitYehudi           3
# YahadutHatora       85
# Balad             5194
# MeimadYarukim        4
# Hadash           11406
# Gimlaim             15
# EfraimSne            6
# IhudLeumi           22
# Israelim            14
# Lev                  4
# NizolimAndAle        4
# Kadima             375
# IsraelBeytenu       54
# Likud              245
# Merez              212
# Nudelman             3
# RuahHadasha          9
# Lazuz                4
# LojmeiHevra          4
# Raam              3862
# Koah               152
# Koah.1               0
# Brit                 5
# Gever                9
# Zomet               18
# Zabar               12
# Daam                50
# AleYarok            18
# Koah.2              18
# Lidar                7
# Yarok               11
# Shas                31
# Name: 30, dtype: object
# i:31. row:TownNumber              8200
# TownName         קרית מוצקין
# Potential              34365
# TotalVotes             22032
# PercentVote            64.11
# Qualified              21656
# Disqualified             376
# Avoda                   2648
# Or                         5
# BaitYehudi               593
# YahadutHatora             68
# Balad                     15
# MeimadYarukim             74
# Hadash                    26
# Gimlaim                  250
# EfraimSne                 53
# IhudLeumi                294
# Israelim                   2
# Lev                        8
# NizolimAndAle             17
# Kadima                  6999
# IsraelBeytenu           4151
# Likud                   4979
# Merez                    297
# Nudelman                  34
# RuahHadasha                5
# Lazuz                      6
# LojmeiHevra                6
# Raam                       8
# Koah                      40
# Koah.1                     0
# Brit                       0
# Gever                     10
# Zomet                      2
# Zabar                     26
# Daam                      16
# AleYarok                  90
# Koah.2                     1
# Lidar                      5
# Yarok                     74
# Shas                     854
# Name: 31, dtype: object
# i:32. row:TownNumber             1061
# TownName         נצרת עילית
# Potential             39340
# TotalVotes            21178
# PercentVote           53.83
# Qualified             20562
# Disqualified            616
# Avoda                   945
# Or                        8
# BaitYehudi              171
# YahadutHatora           132
# Balad                   547
# MeimadYarukim            36
# Hadash                 1280
# Gimlaim                 181
# EfraimSne                24
# IhudLeumi               346
# Israelim                  4
# Lev                      12
# NizolimAndAle            18
# Kadima                 3623
# IsraelBeytenu          7781
# Likud                  4437
# Merez                   174
# Nudelman                 23
# RuahHadasha              10
# Lazuz                     9
# LojmeiHevra               8
# Raam                     90
# Koah                     23
# Koah.1                    0
# Brit                      6
# Gever                     9
# Zomet                    14
# Zabar                    33
# Daam                     46
# AleYarok                 72
# Koah.2                   16
# Lidar                    28
# Yarok                    42
# Shas                    414
# Name: 32, dtype: object
# i:33. row:TownNumber              9500
# TownName         קרית ביאליק
# Potential              32888
# TotalVotes             20414
# PercentVote            62.07
# Qualified              20079
# Disqualified             335
# Avoda                   2491
# Or                         4
# BaitYehudi               232
# YahadutHatora             92
# Balad                     10
# MeimadYarukim             79
# Hadash                    13
# Gimlaim                  187
# EfraimSne                 43
# IhudLeumi                187
# Israelim                   3
# Lev                        9
# NizolimAndAle             24
# Kadima                  6982
# IsraelBeytenu           3656
# Likud                   4602
# Merez                    312
# Nudelman                  16
# RuahHadasha                4
# Lazuz                      4
# LojmeiHevra                3
# Raam                       1
# Koah                      42
# Koah.1                     0
# Brit                       2
# Gever                      7
# Zomet                      9
# Zabar                     38
# Daam                      18
# AleYarok                  99
# Koah.2                     8
# Lidar                     10
# Yarok                     61
# Shas                     831
# Name: 33, dtype: object
# i:34. row:TownNumber          9600
# TownName         קרית ים
# Potential          34786
# TotalVotes         19246
# PercentVote        55.33
# Qualified          18821
# Disqualified         425
# Avoda               1229
# Or                     4
# BaitYehudi           271
# YahadutHatora         71
# Balad                 20
# MeimadYarukim         32
# Hadash                20
# Gimlaim              109
# EfraimSne             35
# IhudLeumi            260
# Israelim               4
# Lev                    9
# NizolimAndAle         18
# Kadima              4665
# IsraelBeytenu       5634
# Likud               4905
# Merez                141
# Nudelman              31
# RuahHadasha            2
# Lazuz                  7
# LojmeiHevra            3
# Raam                   9
# Koah                  83
# Koah.1                 0
# Brit                   6
# Gever                 12
# Zomet                 12
# Zabar                 34
# Daam                  27
# AleYarok              86
# Koah.2                 8
# Lidar                 15
# Yarok                 61
# Shas                 998
# Name: 34, dtype: object
# i:35. row:TownNumber        7700
# TownName         עפולה
# Potential        32576
# TotalVotes       18220
# PercentVote      55.93
# Qualified        17923
# Disqualified       297
# Avoda             1078
# Or                   6
# BaitYehudi         404
# YahadutHatora      120
# Balad               14
# MeimadYarukim       38
# Hadash              13
# Gimlaim             73
# EfraimSne           45
# IhudLeumi          520
# Israelim             9
# Lev                  4
# NizolimAndAle       18
# Kadima            3379
# IsraelBeytenu     4013
# Likud             6245
# Merez              151
# Nudelman            77
# RuahHadasha          8
# Lazuz                9
# LojmeiHevra         10
# Raam                13
# Koah                18
# Koah.1               0
# Brit                 4
# Gever               10
# Zomet                5
# Zabar               55
# Daam                30
# AleYarok            71
# Koah.2              11
# Lidar               14
# Yarok               56
# Shas              1402
# Name: 35, dtype: object
# i:36. row:TownNumber           2640
# TownName         ראש העין
# Potential           26156
# TotalVotes          18111
# PercentVote         69.24
# Qualified           17894
# Disqualified          217
# Avoda                1812
# Or                      3
# BaitYehudi            488
# YahadutHatora         237
# Balad                   1
# MeimadYarukim          89
# Hadash                 40
# Gimlaim                38
# EfraimSne              35
# IhudLeumi             593
# Israelim                0
# Lev                     0
# NizolimAndAle           9
# Kadima               4411
# IsraelBeytenu        1322
# Likud                5915
# Merez                 356
# Nudelman                3
# RuahHadasha             2
# Lazuz                   2
# LojmeiHevra             2
# Raam                    7
# Koah                   11
# Koah.1                  0
# Brit                    3
# Gever                   3
# Zomet                   1
# Zabar                  19
# Daam                    3
# AleYarok               58
# Koah.2                  1
# Lidar                   2
# Yarok                  61
# Shas                 2367
# Name: 36, dtype: object
# i:37. row:TownNumber        2600
# TownName          אילת
# Potential        44156
# TotalVotes       17841
# PercentVote       40.4
# Qualified        17624
# Disqualified       217
# Avoda             1425
# Or                   5
# BaitYehudi         302
# YahadutHatora       84
# Balad               18
# MeimadYarukim      118
# Hadash              74
# Gimlaim             88
# EfraimSne           26
# IhudLeumi          362
# Israelim             5
# Lev                  0
# NizolimAndAle       19
# Kadima            6246
# IsraelBeytenu     2653
# Likud             4327
# Merez              290
# Nudelman            10
# RuahHadasha          2
# Lazuz                3
# LojmeiHevra          4
# Raam                32
# Koah                17
# Koah.1               0
# Brit                 5
# Gever                3
# Zomet                5
# Zabar               33
# Daam                17
# AleYarok           127
# Koah.2               2
# Lidar                2
# Yarok               59
# Shas              1261
# Name: 37, dtype: object
# i:38. row:TownNumber           7200
# TownName         נס ציונה
# Potential           25302
# TotalVotes          17624
# PercentVote         69.65
# Qualified           17459
# Disqualified          165
# Avoda                2636
# Or                      5
# BaitYehudi            337
# YahadutHatora         102
# Balad                   1
# MeimadYarukim         178
# Hadash                 35
# Gimlaim                91
# EfraimSne              63
# IhudLeumi             237
# Israelim                4
# Lev                     2
# NizolimAndAle           6
# Kadima               6450
# IsraelBeytenu        1283
# Likud                4232
# Merez                 557
# Nudelman                6
# RuahHadasha             3
# Lazuz                   5
# LojmeiHevra             5
# Raam                    5
# Koah                   23
# Koah.1                  0
# Brit                    2
# Gever                   5
# Zomet                   4
# Zabar                  38
# Daam                    7
# AleYarok               61
# Koah.2                  6
# Lidar                   6
# Yarok                  79
# Shas                  985
# Name: 38, dtype: object
# i:39. row:TownNumber            2620
# TownName         קרית אונו
# Potential            23408
# TotalVotes           16370
# PercentVote          69.93
# Qualified            16216
# Disqualified           154
# Avoda                 2811
# Or                       1
# BaitYehudi             421
# YahadutHatora           70
# Balad                    2
# MeimadYarukim          150
# Hadash                  49
# Gimlaim                 94
# EfraimSne               50
# IhudLeumi              263
# Israelim                 1
# Lev                      1
# NizolimAndAle           18
# Kadima                5911
# IsraelBeytenu         1034
# Likud                 3764
# Merez                  633
# Nudelman                 4
# RuahHadasha              5
# Lazuz                    5
# LojmeiHevra              5
# Raam                     3
# Koah                    13
# Koah.1                   0
# Brit                     8
# Gever                    3
# Zomet                    9
# Zabar                   16
# Daam                     6
# AleYarok                54
# Koah.2                   7
# Lidar                    2
# Yarok                   80
# Shas                   723
# Name: 39, dtype: object
# i:40. row:TownNumber        6700
# TownName         טבריה
# Potential        32058
# TotalVotes       16233
# PercentVote      50.64
# Qualified        16029
# Disqualified       204
# Avoda              895
# Or                   5
# BaitYehudi         384
# YahadutHatora      423
# Balad                3
# MeimadYarukim       22
# Hadash              11
# Gimlaim             58
# EfraimSne           13
# IhudLeumi          403
# Israelim             1
# Lev                  5
# NizolimAndAle        2
# Kadima            2364
# IsraelBeytenu     2530
# Likud             5684
# Merez               57
# Nudelman             8
# RuahHadasha          2
# Lazuz                5
# LojmeiHevra          1
# Raam                12
# Koah                 6
# Koah.1               0
# Brit                 3
# Gever                3
# Zomet                3
# Zabar               11
# Daam                 9
# AleYarok            48
# Koah.2               3
# Lidar                3
# Yarok               23
# Shas              3029
# Name: 40, dtype: object
# i:41. row:TownNumber        2660
# TownName          יבנה
# Potential        24960
# TotalVotes       16144
# PercentVote      64.68
# Qualified        15929
# Disqualified       215
# Avoda             1493
# Or                   3
# BaitYehudi         378
# YahadutHatora      186
# Balad                1
# MeimadYarukim       56
# Hadash              14
# Gimlaim             45
# EfraimSne           33
# IhudLeumi          539
# Israelim             3
# Lev                  2
# NizolimAndAle       12
# Kadima            4006
# IsraelBeytenu     1523
# Likud             5023
# Merez              264
# Nudelman             3
# RuahHadasha          9
# Lazuz                3
# LojmeiHevra          7
# Raam                 9
# Koah                22
# Koah.1               0
# Brit                 4
# Gever               11
# Zomet                3
# Zabar               27
# Daam                10
# AleYarok            73
# Koah.2               6
# Lidar                8
# Yarok               50
# Shas              2103
# Name: 41, dtype: object
# i:42. row:TownNumber              3616
# TownName         מעלה אדומים
# Potential              22714
# TotalVotes             15071
# PercentVote            66.35
# Qualified              14918
# Disqualified             153
# Avoda                    459
# Or                         1
# BaitYehudi               700
# YahadutHatora            113
# Balad                      1
# MeimadYarukim             53
# Hadash                    13
# Gimlaim                   44
# EfraimSne                 14
# IhudLeumi               1344
# Israelim                   0
# Lev                        1
# NizolimAndAle             10
# Kadima                  1884
# IsraelBeytenu           2255
# Likud                   6645
# Merez                     87
# Nudelman                  12
# RuahHadasha                4
# Lazuz                      1
# LojmeiHevra                2
# Raam                       0
# Koah                       5
# Koah.1                     0
# Brit                       2
# Gever                      0
# Zomet                      3
# Zabar                     22
# Daam                       2
# AleYarok                  42
# Koah.2                     4
# Lidar                      2
# Yarok                     42
# Shas                    1151
# Name: 42, dtype: object
# i:43. row:TownNumber             2710
# TownName         אום אל-פחם
# Potential             24838
# TotalVotes            14660
# PercentVote           59.02
# Qualified             14543
# Disqualified            117
# Avoda                    28
# Or                        0
# BaitYehudi                0
# YahadutHatora             2
# Balad                  3521
# MeimadYarukim             6
# Hadash                 8031
# Gimlaim                   0
# EfraimSne                 3
# IhudLeumi                 8
# Israelim                  3
# Lev                       1
# NizolimAndAle             1
# Kadima                   31
# IsraelBeytenu             7
# Likud                    12
# Merez                    51
# Nudelman                  2
# RuahHadasha               3
# Lazuz                     3
# LojmeiHevra               1
# Raam                   2706
# Koah                      8
# Koah.1                    0
# Brit                      2
# Gever                     2
# Zomet                     3
# Zabar                     3
# Daam                     40
# AleYarok                  8
# Koah.2                    7
# Lidar                     6
# Yarok                     3
# Shas                     41
# Name: 43, dtype: object
# i:44. row:TownNumber            2400
# TownName         אור יהודה
# Potential            24705
# TotalVotes           14234
# PercentVote          57.62
# Qualified            13963
# Disqualified           271
# Avoda                 1215
# Or                       7
# BaitYehudi             408
# YahadutHatora          117
# Balad                    4
# MeimadYarukim           43
# Hadash                  24
# Gimlaim                 61
# EfraimSne               42
# IhudLeumi              212
# Israelim                 2
# Lev                      4
# NizolimAndAle            8
# Kadima                3168
# IsraelBeytenu         1283
# Likud                 4294
# Merez                  182
# Nudelman                 5
# RuahHadasha              0
# ...
# Likud                 2363
# Merez                   33
# Nudelman                 7
# RuahHadasha              2
# Lazuz                    1
# LojmeiHevra              2
# Raam                     3
# Koah                     2
# Koah.1                   0
# Brit                     3
# Gever                    5
# Zomet                    2
# Zabar                    5
# Daam                     8
# AleYarok                26
# Koah.2                   1
# Lidar                    8
# Yarok                   11
# Shas                   869
# Name: 85, dtype: object
# i:86. row:TownNumber             229
# TownName         גני תקווה
# Potential             9699
# TotalVotes            6982
# PercentVote          71.99
# Qualified             6925
# Disqualified            57
# Avoda                 1046
# Or                       1
# BaitYehudi             254
# YahadutHatora          190
# Balad                    2
# MeimadYarukim           32
# Hadash                  15
# Gimlaim                 39
# EfraimSne               14
# IhudLeumi              175
# Israelim                 0
# Lev                      1
# NizolimAndAle            2
# Kadima                2184
# IsraelBeytenu          305
# Likud                 1663
# Merez                  213
# Nudelman                 3
# RuahHadasha              3
# Lazuz                    0
# LojmeiHevra              1
# Raam                     0
# Koah                     5
# Koah.1                   0
# Brit                     3
# Gever                    0
# Zomet                    1
# Zabar                    5
# Daam                     2
# AleYarok                26
# Koah.2                   1
# Lidar                    0
# Yarok                   39
# Shas                   700
# Name: 86, dtype: object
# i:87. row:TownNumber           654
# TownName         כפר קרע
# Potential           9150
# TotalVotes          6363
# PercentVote        69.54
# Qualified           6315
# Disqualified          48
# Avoda                 56
# Or                     0
# BaitYehudi            13
# YahadutHatora          0
# Balad               3566
# MeimadYarukim          5
# Hadash               986
# Gimlaim                0
# EfraimSne             21
# IhudLeumi              5
# Israelim               1
# Lev                    0
# NizolimAndAle          0
# Kadima               116
# IsraelBeytenu          2
# Likud                  8
# Merez                 46
# Nudelman               0
# RuahHadasha            0
# Lazuz                  2
# LojmeiHevra            0
# Raam                1340
# Koah                   2
# Koah.1                 0
# Brit                   1
# Gever                  3
# Zomet                  7
# Zabar                  3
# Daam                  89
# AleYarok               0
# Koah.2                 3
# Lidar                  2
# Yarok                  1
# Shas                  37
# Name: 87, dtype: object
# i:88. row:TownNumber           509
# TownName         כפר כנא
# Potential          10269
# TotalVotes          5964
# PercentVote        58.08
# Qualified           5897
# Disqualified          67
# Avoda                 15
# Or                     2
# BaitYehudi             0
# YahadutHatora         12
# Balad               2358
# MeimadYarukim          0
# Hadash              1746
# Gimlaim                3
# EfraimSne              2
# IhudLeumi              3
# Israelim               2
# Lev                    0
# NizolimAndAle          1
# Kadima                39
# IsraelBeytenu         12
# Likud                 56
# Merez                 53
# Nudelman               0
# RuahHadasha            0
# Lazuz                  6
# LojmeiHevra            0
# Raam                1463
# Koah                  11
# Koah.1                 0
# Brit                   0
# Gever                  1
# Zomet                  9
# Zabar                  2
# Daam                   6
# AleYarok               1
# Koah.2                 0
# Lidar                  3
# Yarok                  4
# Shas                  87
# Name: 88, dtype: object
# i:89. row:TownNumber           638
# TownName         קלנסווה
# Potential           9850
# TotalVotes          5776
# PercentVote        58.64
# Qualified           5714
# Disqualified          62
# Avoda                 17
# Or                     0
# BaitYehudi             0
# YahadutHatora          0
# Balad               1343
# MeimadYarukim          0
# Hadash              1772
# Gimlaim                0
# EfraimSne              0
# IhudLeumi              5
# Israelim               0
# Lev                    0
# NizolimAndAle          0
# Kadima                 6
# IsraelBeytenu          4
# Likud                  6
# Merez                 61
# Nudelman               0
# RuahHadasha            0
# Lazuz                  1
# LojmeiHevra            0
# Raam                2443
# Koah                  34
# Koah.1                 0
# Brit                   1
# Gever                  1
# Zomet                  4
# Zabar                  1
# Daam                   2
# AleYarok               1
# Koah.2                 0
# Lidar                  1
# Yarok                  0
# Shas                  11
# Name: 89, dtype: object
# i:90. row:TownNumber                   9800
# TownName         בנימינה-גבעת עדה
# Potential                    7877
# TotalVotes                   5699
# PercentVote                 72.35
# Qualified                    5643
# Disqualified                   56
# Avoda                         970
# Or                              1
# BaitYehudi                    145
# YahadutHatora                  14
# Balad                           1
# MeimadYarukim                 145
# Hadash                         23
# Gimlaim                        20
# EfraimSne                      13
# IhudLeumi                      83
# Israelim                        1
# Lev                             2
# NizolimAndAle                   1
# Kadima                       2201
# IsraelBeytenu                 370
# Likud                        1026
# Merez                         325
# Nudelman                        1
# RuahHadasha                     0
# Lazuz                           0
# LojmeiHevra                     0
# Raam                            3
# Koah                            3
# Koah.1                          0
# Brit                            0
# Gever                           0
# Zomet                           2
# Zabar                          10
# Daam                            1
# AleYarok                       36
# Koah.2                          0
# Lidar                           0
# Yarok                          19
# Shas                          227
# Name: 90, dtype: object
# i:91. row:TownNumber            1224
# TownName         כוכב יאיר
# Potential             7525
# TotalVotes            5648
# PercentVote          75.06
# Qualified             5625
# Disqualified            23
# Avoda                  902
# Or                       2
# BaitYehudi             271
# YahadutHatora            6
# Balad                    0
# MeimadYarukim           73
# Hadash                  12
# Gimlaim                 24
# EfraimSne                5
# IhudLeumi              128
# Israelim                 0
# Lev                      1
# NizolimAndAle            3
# Kadima                2119
# IsraelBeytenu          338
# Likud                 1348
# Merez                  276
# Nudelman                 0
# RuahHadasha              2
# Lazuz                    0
# LojmeiHevra              0
# Raam                     0
# Koah                     3
# Koah.1                   0
# Brit                     0
# Gever                    1
# Zomet                    2
# Zabar                   15
# Daam                     1
# AleYarok                24
# Koah.2                   0
# Lidar                    0
# Yarok                   32
# Shas                    37
# Name: 91, dtype: object
# i:92. row:TownNumber            510
# TownName         כפר מנדא
# Potential            8229
# TotalVotes           5607
# PercentVote         68.14
# Qualified            5458
# Disqualified          149
# Avoda                 110
# Or                      0
# BaitYehudi              0
# YahadutHatora           0
# Balad                1369
# MeimadYarukim           0
# Hadash               1324
# Gimlaim                 0
# EfraimSne               3
# IhudLeumi               3
# Israelim                2
# Lev                     0
# NizolimAndAle           2
# Kadima                 59
# IsraelBeytenu           2
# Likud                  11
# Merez                   8
# Nudelman                0
# RuahHadasha             0
# Lazuz                   0
# LojmeiHevra             1
# Raam                 1836
# Koah                    2
# Koah.1                  0
# Brit                    0
# Gever                   3
# Zomet                   5
# Zabar                   0
# Daam                  133
# AleYarok                0
# Koah.2                  4
# Lidar                   3
# Yarok                   0
# Shas                  578
# Name: 92, dtype: object
# i:93. row:TownNumber         637
# TownName         ערערה
# Potential         9672
# TotalVotes        5429
# PercentVote      56.13
# Qualified         5386
# Disqualified        43
# Avoda                6
# Or                   0
# BaitYehudi           0
# YahadutHatora        1
# Balad             2367
# MeimadYarukim        8
# Hadash            1109
# Gimlaim              1
# EfraimSne            0
# IhudLeumi            2
# Israelim             2
# Lev                  0
# NizolimAndAle        0
# Kadima              12
# IsraelBeytenu        4
# Likud                8
# Merez               74
# Nudelman             1
# RuahHadasha          1
# Lazuz                4
# LojmeiHevra          1
# Raam              1734
# Koah                 1
# Koah.1               0
# Brit                 0
# Gever                6
# Zomet                8
# Zabar                4
# Daam                21
# AleYarok             2
# Koah.2               1
# Lidar                2
# Yarok                1
# Shas                 5
# Name: 93, dtype: object
# i:94. row:TownNumber             182
# TownName         אבן יהודה
# Potential             7508
# TotalVotes            5352
# PercentVote          71.28
# Qualified             5319
# Disqualified            33
# Avoda                  998
# Or                       1
# BaitYehudi             124
# YahadutHatora           38
# Balad                    0
# MeimadYarukim           50
# Hadash                  16
# Gimlaim                 31
# EfraimSne               12
# IhudLeumi               73
# Israelim                 0
# Lev                      0
# NizolimAndAle            3
# Kadima                2108
# IsraelBeytenu          263
# Likud                 1096
# Merez                  263
# Nudelman                 0
# RuahHadasha              1
# Lazuz                    0
# LojmeiHevra              0
# Raam                     2
# Koah                     6
# Koah.1                   0
# Brit                     0
# Gever                    1
# Zomet                    3
# Zabar                    5
# Daam                     1
# AleYarok                26
# Koah.2                   1
# Lidar                    0
# Yarok                   24
# Shas                   173
# Name: 94, dtype: object
# i:95. row:TownNumber           3730
# TownName         גבעת זאב
# Potential            7663
# TotalVotes           5314
# PercentVote         69.35
# Qualified            5262
# Disqualified           52
# Avoda                 231
# Or                      1
# BaitYehudi            144
# YahadutHatora         159
# Balad                   1
# MeimadYarukim          50
# Hadash                  1
# Gimlaim                29
# EfraimSne               6
# IhudLeumi             298
# Israelim                1
# Lev                     0
# NizolimAndAle           8
# Kadima                895
# IsraelBeytenu         463
# Likud                2294
# Merez                  50
# Nudelman                1
# RuahHadasha             0
# Lazuz                   1
# LojmeiHevra             0
# Raam                    0
# Koah                    3
# Koah.1                  0
# Brit                    1
# Gever                   0
# Zomet                   4
# Zabar                   8
# Daam                    0
# AleYarok               21
# Koah.2                  0
# Lidar                   2
# Yarok                  34
# Shas                  556
# Name: 95, dtype: object
# i:96. row:TownNumber         565
# TownName          אזור
# Potential         8438
# TotalVotes        5293
# PercentVote      62.73
# Qualified         5206
# Disqualified        87
# Avoda              608
# Or                   1
# BaitYehudi          96
# YahadutHatora       41
# Balad                1
# MeimadYarukim       18
# Hadash               5
# Gimlaim             31
# EfraimSne           23
# IhudLeumi           71
# Israelim             3
# Lev                  0
# NizolimAndAle       10
# Kadima            1651
# IsraelBeytenu      652
# Likud             1467
# Merez               90
# Nudelman             8
# RuahHadasha          0
# Lazuz                0
# LojmeiHevra          3
# Raam                 2
# Koah                 3
# Koah.1               0
# Brit                 0
# Gever                0
# Zomet                0
# Zabar                4
# Daam                 2
# AleYarok            24
# Koah.2               0
# Lidar                0
# Yarok               20
# Shas               372
# Name: 96, dtype: object
# i:97. row:TownNumber         502
# TownName          ירכא
# Potential         7742
# TotalVotes        5176
# PercentVote      66.86
# Qualified         5062
# Disqualified       114
# Avoda              850
# Or                   2
# BaitYehudi           4
# YahadutHatora        0
# Balad              194
# MeimadYarukim        1
# Hadash             502
# Gimlaim              2
# EfraimSne            6
# IhudLeumi            1
# Israelim             4
# Lev                  1
# NizolimAndAle        3
# Kadima             385
# IsraelBeytenu     1058
# Likud              449
# Merez               14
# Nudelman             0
# RuahHadasha          1
# Lazuz                0
# LojmeiHevra          0
# Raam                 6
# Koah                 0
# Koah.1               0
# Brit                 2
# Gever                1
# Zomet              191
# Zabar                3
# Daam                 8
# AleYarok            12
# Koah.2               0
# Lidar               11
# Yarok                7
# Shas              1344
# Name: 97, dtype: object
# i:98. row:TownNumber              1292
# TownName         ג'דיידה-מכר
# Potential              10566
# TotalVotes              5118
# PercentVote            48.44
# Qualified               5047
# Disqualified              71
# Avoda                     19
# Or                         1
# BaitYehudi                 3
# YahadutHatora              3
# Balad                   1991
# MeimadYarukim              3
# Hadash                  1510
# Gimlaim                    3
# EfraimSne                  1
# IhudLeumi                  9
# Israelim                   1
# Lev                        1
# NizolimAndAle              2
# Kadima                    23
# IsraelBeytenu              9
# Likud                      7
# Merez                     35
# Nudelman                   3
# RuahHadasha                0
# Lazuz                      4
# LojmeiHevra                0
# Raam                    1387
# Koah                       2
# Koah.1                     0
# Brit                       2
# Gever                      0
# Zomet                      3
# Zabar                      2
# Daam                       5
# AleYarok                   3
# Koah.2                     2
# Lidar                      2
# Yarok                      2
# Shas                       9
# Name: 98, dtype: object
# i:99. row:TownNumber           154
# TownName         תל מונד
# Potential           6768
# TotalVotes          4890
# PercentVote        72.25
# Qualified           4852
# Disqualified          38
# Avoda                774
# Or                     1
# BaitYehudi            97
# YahadutHatora         20
# Balad                  0
# MeimadYarukim         45
# Hadash                 5
# Gimlaim               13
# EfraimSne             12
# IhudLeumi             58
# Israelim               0
# Lev                    0
# NizolimAndAle          1
# Kadima              1919
# IsraelBeytenu        251
# Likud               1139
# Merez                153
# Nudelman               1
# RuahHadasha            1
# Lazuz                  0
# LojmeiHevra            2
# Raam                   4
# Koah                  11
# Koah.1                 0
# Brit                   0
# Gever                  1
# Zomet                  1
# Zabar                  6
# Daam                   2
# AleYarok              19
# Koah.2                 1
# Lidar                  0
# Yarok                 25
# Shas                 290
# Name: 99, dtype: object

# %%
# Number of cities to cluster (they are ordered by the total number of votes, descending)
n = 100

# Data matrix and labels list (41 columns - metadata ones)
x = np.zeros((n, 34))
labels_r = []

# Iterate over rows in dataframe
for i, row in df[:n].iterrows():
    x[i] = row[7:]                         # take only the votes, not the other meta-data
    labels_r.append(df.TownName[i][::-1])  # reverse the labels (because they are in Hebrew)

# Normalize rows (so they represent proportions):
x = x/(np.sum(x, axis=1).reshape(-1, 1))

# %%
# You can experiment with the different methods ('single', 'complete', 'average', 'ward'):
# (Note that we don't use squareform here, so the linkage function will assume by
# default that x is not a distance matrix but a set of observations, and will calculate
# the euclidean distance between them. We could, instead, calculate our own distance
# matrix using other distance measures between distributions, for example the Kullback-
# Leibler divergence (relative entropy).)
lnk = hierarchy.linkage(x, 'average')

# %%
plt.figure(figsize=(20, 5))

# You can experiment with the color threshold to observe the different possible clusterizations:
hierarchy.dendrogram(lnk, labels=labels_r, leaf_font_size=14, color_threshold=0.5);

# %% [markdown]
# ## Challenge 1.2
# When using our domain expertise regarding the population in Israeli cities and villages, we can cleary conclude from the results that our society is mainly splitted according to their "religiosity". Although the jingle says "there's no more right or left", your mission, should you choose to accept it, is to find a way to distinguish between right and left.

# %%
# Add your code for Challenge 1.2 after this line, and keep it in this cell.

# my hebrew/politic knowledge is not that good :)

modes = ['centroid', 'complete']
thresholds = [0.5, 0.7]

for mode, threshold in zip(modes, thresholds):
    plt.figure(figsize=(20, 5))
    # You can experiment with the color threshold to observe the different possible clusterizations:
    lnk = hierarchy.linkage(x, mode)
    hierarchy.dendrogram(lnk, labels=labels_r, leaf_font_size=14, color_threshold=threshold);

# %% [markdown]
# ## Part 2 - DBSCAN

# %% [markdown]
# Original code was taken from those sources:
#
# https://towardsdatascience.com/dbscan-clustering-for-data-shapes-k-means-cant-handle-well-in-python-6be89af4e6ea
#
# In this part of the exercise, we will experiment with the DBSCAN algorithm on a synthetic set of data

# %%
# auxilary plotting functions
def plot(X):
    plt.scatter(X[:, 0], X[:, 1])
    plt.xlabel("Feature 0")
    plt.ylabel("Feature 1")
    plt.show()
    
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %%
# generate some random cluster data
X, y = make_blobs(random_state=170, n_samples=500, centers = 5)
rng = np.random.RandomState(74)
# transform the data to be stretched
transformation = rng.normal(size=(2, 2))
X = np.dot(X, transformation)

plot(X)

# %%
# Adding Noise to data
outliers = 30 * (np.random.RandomState(42).rand(100, 2) ) - 15.0
X = np.concatenate([X, outliers])
y = np.concatenate([y, [-1]*len(outliers)])
plot(X)

# %% [markdown]
# ### K-Means attempt
# Lets see how those outliers and non-spherical shapes affects K-Means clustreing

# %%
# cluster the data into five clusters
n_clusters = 5
kmeans = KMeans(n_clusters=n_clusters)
kmeans.fit(X)
kmeans_clusters = kmeans.predict(X)
# plot the cluster assignments and cluster centers
plt.scatter(X[:, 0], X[:, 1], c=kmeans_clusters, cmap="plasma")
plt.title("K-Means attempt")
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
# Out:
# Text(0, 0.5, 'Feature 1')

# %% [markdown]
# Not surprisingly, K-Means failed to cluster properly the data above
#
# As we saw in the lecture, DBSCAN can overcome those issues. Yet we still need to determine the parametrs...

# %% [markdown]
# # Estimateing $\varepsilon$

# %% [markdown]
# ## Challenge 2.1
#
# Your co-worker suggested a way to select $\epsilon$ of dbscan.
# He wants to go over different eps values and find the one that maximizes the silhouette value.
# Implement the algorithm and find the best $\epsilon$ using this method.
# 1. Create an array of possible $\epsilon$ values.
# 2. Iterate over the different values and find the best $\epsilon$ value. What is it?
# 3. Visualize the results of the best one.

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics.cluster import adjusted_rand_score

# %%
score_func_enum = {'adjusted rand score' : adjusted_rand_score, 
                  'calinski_harabasz_score' : calinski_harabasz_score, 
                  'silhouette_score' : silhouette_score}
for a,b in enumerate(score_func_enum):
    print(b)
# Out:
# adjusted rand score
# calinski_harabasz_score
# silhouette_score

# %%
# minPts are given and are not required to be estimated.
# Yet, in the cells after completing the task feel free to play with it and get better result if you can!
minPts = 50 
# YOUR CODE HERE - keep results in this cell



min_eps = 0.15
step = 0.01
max_eps = min_eps + 1
best_eps = min_eps


def defineBestEps(min_eps, max_eps, step):
    score = 0
    best_score = 0
    list_score = []
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    list_eps = np.arange(min_eps, max_eps, step)
    for i, eps in enumerate(list_eps):
        dbscan = DBSCAN(eps=eps, min_samples=minPts)
        clusters = dbscan.fit_predict(X_scaled)
        score = adjusted_rand_score(clusters, y)
        list_score.append(score)
        if score > best_score:
            best_score = score
            best_eps = eps
    plt.plot(list_eps, list_score, label="rand_score")
    plt.xlabel("Eps")
#     plt.grid(True)
    plt.ylabel("Score")
    plt.legend()
    plt.show()
    return best_eps, best_score, X_scaled


best_eps1, best_score, X_scaled  = defineBestEps(min_eps, max_eps, step)
best_eps, best_score, X_scaled = defineBestEps(best_eps1 - step, best_eps1 + step, step/100)
print("best_score:{}, best_eps:{}".format(best_score, best_eps ))
dbscan = DBSCAN(eps=best_eps, min_samples=minPts)#min_samples = 2
clusters = dbscan.fit_predict(X_scaled)
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap="plasma")
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.show()
# Out:
# best_score:0.7734211347708075, best_eps:0.23559999999999834

# %%
clustering = OPTICS(min_samples=50).fit(X)
optics_clusters = clustering.labels_
a = plt.scatter(X[:,0], X[:,1], c=optics_clusters, cmap="plasma")
print(set(optics_clusters))
# Out:
# {0, 1, 2, 3, -1}

# %% [markdown]
# How many values of $\epsilon$ did you iterate? can you find a way to narrow down the range of the search?

# %% [markdown]
# ## Challenge 2.2
#
#
# Support yout findings by plotting the _k-dist_ graph of the data with the given $minPts$, and repeat the above process with a more precise range of $\epsilon$.
#
# Did you manage to find a better $\epsilon$?
#
# visualize the new results.

# %%
from sklearn.neighbors import NearestNeighbors

def plotKDist(data, numNeighbours):
    # YOUR CODE HERE
    nb = NearestNeighbors(n_neighbors=numNeighbours)
    nbrs = nb.fit(data)
    dist, indice = nbrs.kneighbors(data)
    dist = np.sort(dist, axis=0)
    dist = dist[:, 1]
    plt.plot(dist)
   # plt.xlim((500, 600))
    plt.axhline(best_eps, color='black')
    plt.show()
    return dist, dist[numNeighbours]
    
    
def masks(vec):
    d = np.diff(vec)
    dd = np.diff(d)
    dd = np.append(dd, dd[-1])
    return np.append(dd, dd[-1])


# Find an epsilon according to the k-dist graph - keep reuslts in this cell
eps_tab, eps = plotKDist(X, minPts)    
dd = masks(eps_tab)


# YOUR CODE HERE

# %%
# Repeat Challenge 2.1 process with a range around the epsilon you found via k-dist graph
# Visualize the results - keep all results in this cell

# YOUR CODE HERE



# I have kind of mixed the previous questions

# %% [markdown]
# # Good Luck and Enjoy Learning Machine Learning!
